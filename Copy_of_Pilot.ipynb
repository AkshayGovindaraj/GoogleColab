# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshayGovindaraj/GoogleColab/blob/main/Copy_of_Pilot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
x = y = z = 4

# %%
x
y
z
# Out:
# 4

# %%
y
# Out:
# 4

# %%
a = "Great Learning"

# %%
a
# Out:
# 'Great Learning'

# %%
a, b, c = 5 , 5, "Great Learning"

# %%
a
b
c
# Out:
# 'Great Learning'

# %%
type(a)
# Out:
# int

# %%
type(c)
# Out:
# str

# %%
z = 3 + 4j

# %%
type(z)
# Out:
# complex

# %%
var = True
type(var)
# Out:
# bool

# %%
bool
# Out:
# bool

# %%
10>3
# Out:
# True

# %%
float(3>1)
# Out:
# 1.0

# %%
int(11.7)
# Out:
# 11

# %%
int(-11.3)
# Out:
# -11

# %%
print("x =", a, end='\n\n')
print(y)
# Out:
# x = 5
#
# 4
