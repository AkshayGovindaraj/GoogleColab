# %% [markdown]
# # Project Python Foundations: FoodHub Data Analysis

# %% [markdown]
# ### Context
#
# The number of restaurants in New York is increasing day by day. Lots of students and busy professionals rely on those restaurants due to their hectic lifestyles. Online food delivery service is a great option for them. It provides them with good food from their favorite restaurants. A food aggregator company FoodHub offers access to multiple restaurants through a single smartphone app.
#
# The app allows the restaurants to receive a direct online order from a customer. The app assigns a delivery person from the company to pick up the order after it is confirmed by the restaurant. The delivery person then uses the map to reach the restaurant and waits for the food package. Once the food package is handed over to the delivery person, he/she confirms the pick-up in the app and travels to the customer's location to deliver the food. The delivery person confirms the drop-off in the app after delivering the food package to the customer. The customer can rate the order in the app. The food aggregator earns money by collecting a fixed margin of the delivery order from the restaurants.
#
# ### Objective
#
# The food aggregator company has stored the data of the different orders made by the registered customers in their online portal. They want to analyze the data to get a fair idea about the demand of different restaurants which will help them in enhancing their customer experience. Suppose you are hired as a Data Scientist in this company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
# ### Data Description
#
# The data contains the different data related to a food order. The detailed data dictionary is given below.
#
# ### Data Dictionary
#
# * order_id: Unique ID of the order
# * customer_id: ID of the customer who ordered the food
# * restaurant_name: Name of the restaurant
# * cuisine_type: Cuisine ordered by the customer
# * cost_of_the_order: Cost of the order
# * day_of_the_week: Indicates whether the order is placed on a weekday or weekend (The weekday is from Monday to Friday and the weekend is Saturday and Sunday)
# * rating: Rating given by the customer out of 5
# * food_preparation_time: Time (in minutes) taken by the restaurant to prepare the food. This is calculated by taking the difference between the timestamps of the restaurant's order confirmation and the delivery person's pick-up confirmation.
# * delivery_time: Time (in minutes) taken by the delivery person to deliver the food package. This is calculated by taking the difference between the timestamps of the delivery person's pick-up confirmation and drop-off information

# %% [markdown]
# ### Let us start by importing the required libraries

# %%
# Installing the libraries with the specified version.
# !pip install numpy==2.0.2 pandas==2.2.2 matplotlib==3.10.0 seaborn==0.13.2 -q --user

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Understanding the structure of the data

# %%
# uncomment and run the below code snippets if the dataset is present in the Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Write your code here to read the data
df = pd.read_csv('foodhub_order.csv')

# %%
# Write your code here to view the first 5 rows
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %% [markdown]
# ### **Question 1:** How many rows and columns are present in the data? [0.5 mark]

# %%
# Write your code here
df.shape
# Out:
# (1898, 9)

# %% [markdown]
# #### Observations:
# There are 1898 rows and 9 columns in ther dataset

# %% [markdown]
# ### **Question 2:** What are the datatypes of the different columns in the dataset? (The info() function can be used) [0.5 mark]

# %%
# Write your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %% [markdown]
# #### Observations:
# 1) The following fileds are integers and are fairly so: order_id, customer_id, food_preparation_time, delivery_time.
# 2) day_of_the_week is an object (string) and it would be better to convert that to datetime format.
# 3) rating is an object (string) but it should be an integer. Perhaps some orders are not rated and therefore it is a string.
# 4) restaurant_name and cuisine_type are objects (strings) and should remain so. They could be treated as categorical variables.

# %% [markdown]
# ### **Question 3:** Are there any missing values in the data? If yes, treat them using an appropriate method. [1 mark]

# %%
# Write your code here
df.isna().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                         count unique          top  freq           mean  \
# order_id               1898.0    NaN          NaN   NaN      1477495.5
# customer_id            1898.0    NaN          NaN   NaN  171168.478398
# restaurant_name          1898    178  Shake Shack   219            NaN
# cuisine_type             1898     14     American   584            NaN
# cost_of_the_order      1898.0    NaN          NaN   NaN      16.498851
# day_of_the_week          1898      2      Weekend  1351            NaN
# rating                   1898      4    Not given   736            NaN
# food_preparation_time  1898.0    NaN          NaN   NaN       27.37197
# delivery_time          1898.0    NaN          NaN   NaN      24.161749
#
#                                  std        min         25%        50%  \
# order_id                  548.049724  1476547.0  1477021.25  1477495.5
# customer_id            113698.139743     1311.0    77787.75   128600.0
# restaurant_name                  NaN        NaN         NaN        NaN
# cuisine_type                     NaN        NaN         NaN        NaN
# cost_of_the_order           7.483812       4.47       12.08      14.14
# day_of_the_week                  NaN        NaN         NaN        NaN
# rating                           NaN        NaN         NaN        NaN
# food_preparation_time       4.632481       20.0        23.0       27.0
# delivery_time               4.972637       15.0        20.0       25.0
#
#                               75%        max
# order_id               1477969.75  1478444.0
# customer_id              270525.0   405334.0
# restaurant_name               NaN        NaN
# cuisine_type                  NaN        NaN
# cost_of_the_order         22.2975      35.41
# day_of_the_week               NaN        NaN
# rating                        NaN        NaN
# food_preparation_time        31.0       35.0
# delivery_time                28.0       33.0

# %%
df.groupby(['rating'])['rating'].count().loc['3']
# Out:
# np.int64(188)

# %% [markdown]
# #### Observations:
# There are no fields in any of the row which are null or NaN in this dataset. So it seems all numeric variables have the data. Some orders were not rated and therefore the ratings field has 'Not Missing' as value in some of the rows.
#
# There are ratings which are 'Not given'. THose should perhaps we replaced by the mean ratings.

# %%
mean = pd.to_numeric(df['rating'], errors='coerce').mean()
mean
# Out:
# np.float64(4.344234079173838)

# %% [markdown]
# The above code calculates the mean of all ratings given. THat turns out to be 4.34. So we will replace all 'Not given' with 4.34

# %%
df['rating_adjusted'] = pd.to_numeric(df['rating'].replace(['Not given'], 4.34))

# %%
df.groupby(['rating_adjusted'])['rating_adjusted'].count()
# Out:
# rating_adjusted
# 3.00    188
# 4.00    386
# 4.34    736
# 5.00    588
# Name: rating_adjusted, dtype: int64

# %% [markdown]
# This make it possible to calculate correlations or understand any kind of relation with other factors.

# %% [markdown]
# ### **Question 4:** Check the statistical summary of the data. What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed? [2 marks]

# %%
# Write your code here
df.describe(include='all').T
# Out:
#                         count unique          top  freq           mean  \
# order_id               1898.0    NaN          NaN   NaN      1477495.5
# customer_id            1898.0    NaN          NaN   NaN  171168.478398
# restaurant_name          1898    178  Shake Shack   219            NaN
# cuisine_type             1898     14     American   584            NaN
# cost_of_the_order      1898.0    NaN          NaN   NaN      16.498851
# day_of_the_week          1898      2      Weekend  1351            NaN
# rating                   1898      4    Not given   736            NaN
# food_preparation_time  1898.0    NaN          NaN   NaN       27.37197
# delivery_time          1898.0    NaN          NaN   NaN      24.161749
# rating_adjusted        1898.0    NaN          NaN   NaN       4.342592
#
#                                  std        min         25%        50%  \
# order_id                  548.049724  1476547.0  1477021.25  1477495.5
# customer_id            113698.139743     1311.0    77787.75   128600.0
# restaurant_name                  NaN        NaN         NaN        NaN
# cuisine_type                     NaN        NaN         NaN        NaN
# cost_of_the_order           7.483812       4.47       12.08      14.14
# day_of_the_week                  NaN        NaN         NaN        NaN
# rating                           NaN        NaN         NaN        NaN
# food_preparation_time       4.632481       20.0        23.0       27.0
# delivery_time               4.972637       15.0        20.0       25.0
# rating_adjusted             0.580074        3.0         4.0       4.34
#
#                               75%        max
# order_id               1477969.75  1478444.0
# customer_id              270525.0   405334.0
# restaurant_name               NaN        NaN
# cuisine_type                  NaN        NaN
# cost_of_the_order         22.2975      35.41
# day_of_the_week               NaN        NaN
# rating                        NaN        NaN
# food_preparation_time        31.0       35.0
# delivery_time                28.0       33.0
# rating_adjusted               5.0        5.0

# %% [markdown]
# #### Observations:
# Food Preparation Time:
# 1) Minimum: 20 minutes
# 2) Average: 27.37 minutes
# 3) Maximum: 35 minutes

# %% [markdown]
# ### **Question 5:** How many orders are not rated? [1 mark]

# %%
# Write the code here
df['rating'].value_counts()
# Out:
# rating
# Not given    736
# 5            588
# 4            386
# 3            188
# Name: count, dtype: int64

# %% [markdown]
# #### Observations:
#
# There were a total of 736  orders out of 1898 which were not rated.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### **Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [9 marks]

# %%
# Write the code here
sns.histplot(data=df['cost_of_the_order']);

# %%
sns.histplot(data=df['food_preparation_time'], bins=16);

# %%
sns.histplot(data=df['delivery_time'], binwidth=1)
# Out:
# <Axes: xlabel='delivery_time', ylabel='Count'>

# %%
sns.countplot(data=df['cuisine_type'])
plt.xticks(rotation=90)
plt.show()
#

# %%
sns.countplot(data=df['day_of_the_week'])
plt.xticks(rotation=90)
plt.show()
#

# %%
df['restaurant_name'].value_counts()
# Out:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
#                             ...
# Rye House                      1
# Hiroko's Place                 1
# Frank Restaurant               1
# Sarabeth's West                1
# 'wichcraft                     1
# Name: count, Length: 178, dtype: int64

# %%
sns.countplot(data=df['rating'])
# Out:
# <Axes: xlabel='count', ylabel='rating'>

# %% [markdown]
# ### **Question 7**: Which are the top 5 restaurants in terms of the number of orders received? [1 mark]

# %%
# Write the code here
df[['restaurant_name']].value_counts().head()
# Out:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
# Name: count, dtype: int64

# %% [markdown]
# #### Observations:
# The top 5 restaurants are:
# 1) Shake Shack
# 2) The Meatball Shop
# 3) Blue Ribbon Sushi
# 4) Blue Ribbon Fried Chicken
# 5) Parm
#
# Pandas value_counts() function will order them in desending order and therefore it can be used for this purpose.

# %% [markdown]
# ### **Question 8**: Which is the most popular cuisine on weekends? [1 mark]

# %%
# Write the code here
df[df['day_of_the_week']=='Weekend']['cuisine_type'].value_counts().head()
# Out:
# cuisine_type
# American    415
# Japanese    335
# Italian     207
# Chinese     163
# Mexican      53
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='cuisine_type', hue='day_of_the_week')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observations:
# The most popular cuisine in weekends is American which is closely followed by Japanese. The distribution is fairly similar for weekdays and weekends.

# %% [markdown]
# ### **Question 9**: What percentage of the orders cost more than 20 dollars? [2 marks]

# %%
# Write the code here
df[df['cost_of_the_order']>20].value_counts().sum()/df.shape[0]*100
# Out:
# np.float64(29.24130663856691)

# %% [markdown]
# #### Observations:
# 29.24% of the orders have a cost of more than $20.

# %% [markdown]
# ### **Question 10**: What is the mean order delivery time? [1 mark]

# %%
# Write the code here
df['delivery_time'].mean()
# Out:
# np.float64(24.161749209694417)

# %% [markdown]
# #### Observations:
# The mean delivery time is 24.16 minutes.
#
# One observation is that this is higher than the mean preparation time (27 minutes). Therefore, the delivery time is perhaps only the time after preparation to delivery. The total order time would be the sum of preparation time and the delivery time.

# %% [markdown]
# ### **Question 11:** The company has decided to give 20% discount vouchers to the top 3 most frequent customers. Find the IDs of these customers and the number of orders they placed. [1 mark]

# %%
# Write the code here
df['customer_id'].value_counts().head(3)
# Out:
# customer_id
# 52832    13
# 47440    10
# 83287     9
# Name: count, dtype: int64

# %% [markdown]
# #### Observations:
#
# The top 3 most frequent customers are:
#
# 1) 52832 (customer_id) - 13 orders
# 2) 47440 - 10 orders
# 3) 83287 - 9 orders

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ### **Question 12**: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables) [10 marks]

# %%
# Write the code here
sns.histplot(data=df, x='cost_of_the_order', hue='cuisine_type', binwidth =1, kde='True', multiple='stack');

# %% [markdown]
# Observation: Based on the kde lines we don't see any trend. All cuisines have a wide price range. In other words, the price doesn't depend on the cuisine.

# %%
sns.histplot(data=df, x='cost_of_the_order', hue='day_of_the_week', binwidth =1, kde='True', multiple = 'stack');

# %% [markdown]
# Observation: We may have expected the order cost to be higher during weeekends but it is somewhat similar to Weekdays based on the above chart.

# %%
sns.heatmap(data=df[['cost_of_the_order', 'rating_adjusted', 'food_preparation_time', 'delivery_time']].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Observation: Based on the correlation plot we don't see a stronger correlation between any two pairs of numeric variables. THis needs to be confirmed with scatterplots.

# %%
sns.pairplot(data=df[['cost_of_the_order', 'rating_adjusted', 'food_preparation_time', 'delivery_time']])

# %% [markdown]
# Confirmed that there isn't a strong correlation betweeen the numeric variables. Perhaps there are dependecies between categorical variables.

# %%
df.groupby('cuisine_type')['rating_adjusted'].mean()
# Out:
# cuisine_type
# American          4.314110
# Chinese           4.338977
# French            4.317778
# Indian            4.476986
# Italian           4.351812
# Japanese          4.359532
# Korean            4.181538
# Mediterranean     4.255652
# Mexican           4.387792
# Middle Eastern    4.267347
# Southern          4.315294
# Spanish           4.586667
# Thai              4.494737
# Vietnamese        4.097143
# Name: rating_adjusted, dtype: float64

# %% [markdown]
# Observation: Some cuisine types seem to have a lower than average rating. Vietnamese and Korean are less than 4.2 and perhaps the company needs to look for better restaurants there. Its possible that there are just fewer orders in two cusine types and therefore the average ratings are less indicative of the kind of restaurants onboarded.

# %% [markdown]
# ### **Question 13:** The company wants to provide a promotional offer in the advertisement of the restaurants. The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4. Find the restaurants fulfilling the criteria to get the promotional offer. [3 marks]

# %%
# Write the code here
restaurant_df1 = df.groupby('restaurant_name', as_index=False).agg({
    'rating_adjusted': 'mean',
    'order_id': 'count'
})
restaurant_df1
# Out:
#       restaurant_name  rating_adjusted  order_id
# 0          'wichcraft         5.000000         1
# 1           12 Chairs         4.420000         4
# 2     5 Napkin Burger         4.204000         5
# 3           67 Burger         5.000000         1
# 4             Alidoro         4.340000         1
# ..                ...              ...       ...
# 173    Zero Otto Nove         4.170000         2
# 174              brgr         3.670000         2
# 175        da Umberto         4.560000         3
# 176  ilili Restaurant         4.205556        18
# 177         indikitch         4.420000         4
#
# [178 rows x 3 columns]

# %% [markdown]
# The above will create a new dataframe with the rating_adjusted colume giving the average ratings and the order_id column giving the total number of orders.

# %%
restaurant_df1.loc[(restaurant_df1['rating_adjusted']>4) & (restaurant_df1['order_id']>50)]
# Out:
#                restaurant_name  rating_adjusted  order_id
# 20   Blue Ribbon Fried Chicken         4.332083        96
# 21           Blue Ribbon Sushi         4.265882       119
# 109                       Parm         4.218529        68
# 121           RedFarm Broadway         4.273220        59
# 122             RedFarm Hudson         4.238909        55
# 136                Shake Shack         4.302466       219
# 153          The Meatball Shop         4.449394       132

# %% [markdown]
# #### Observations:
# The restaurants that qualify are the following:
# 1) Blue Ribbon Fried Chicken
# 2) Blue Ribbon Sushi
# 3) Parm
# 4) RedFarm Broadway
# 5) RedFarm Hudson
# 6) Shake Shack
# 7) The Meatball Shop

# %% [markdown]
# ### **Question 14:** The company charges the restaurant 25% on the orders having cost greater than 20 dollars and 15% on the orders having cost greater than 5 dollars. Find the net revenue generated by the company across all orders. [3 marks]

# %%
# Write the code here
def order_revenue(order_cost):
  if(order_cost>20): return (order_cost*0.25)
  elif(order_cost>5): return (order_cost*0.15)
  else: return 0

# %%
# Write the code here
net_revenue = 0
for order_cost in df['cost_of_the_order']: net_revenue += order_revenue(order_cost)
print(net_revenue)
# Out:
# 6166.302999999994

# %%
df['cost_of_the_order'].sum()
# Out:
# np.float64(31314.82)

# %% [markdown]
# #### Observations:
# ## The company revenue is $6,166.30.
#
# The margin is about 20%

# %% [markdown]
# ### **Question 15:** The company wants to analyze the total time required to deliver the food. What percentage of orders take more than 60 minutes to get delivered from the time the order is placed? (The food has to be prepared and then delivered.) [2 marks]

# %%
df['total_time'] = df['food_preparation_time'] + df['delivery_time']

# %%
df[df['total_time']>60]['total_time'].count()/df['total_time'].count()
# Out:
# np.float64(0.1053740779768177)

# %% [markdown]
# #### Observations:
# About 10.5% of the orders have a total time of more than 60 minutes. It would be interesting to see if that has an impact on the ratings.

# %%
sns.histplot(data=df, x='total_time', hue='rating_adjusted', multiple='stack')
# Out:
# <Axes: xlabel='total_time', ylabel='Count'>

# %% [markdown]
# It doesn't look like the ratings are strongly dependent on the delivery time. Customer satisfaction has a strong dependency on other factors.

# %% [markdown]
# ### **Question 16:** The company wants to analyze the delivery time of the orders on weekdays and weekends. How does the mean delivery time vary during weekdays and weekends? [2 marks]

# %%
# Write the code here
df[df['day_of_the_week']=='Weekday']['delivery_time'].mean()
# Out:
# np.float64(28.340036563071298)

# %%
df[df['day_of_the_week']=='Weekend']['delivery_time'].mean()
# Out:
# np.float64(22.4700222057735)

# %% [markdown]
# #### Observations: The delivery time on a weekend is faster than that of a weekday. It is 6 minutes faster on average with Weekend average being 22 minutes and weekday average being 28 minutes.

# %%
sns.histplot(data=df, x='delivery_time',hue='day_of_the_week', multiple='stack')
# Out:
# <Axes: xlabel='delivery_time', ylabel='Count'>

# %%
df.groupby('day_of_the_week')['rating_adjusted'].mean()
# Out:
# day_of_the_week
# Weekday    4.320622
# Weekend    4.351488
# Name: rating_adjusted, dtype: float64

# %%
df.groupby('day_of_the_week')['cost_of_the_order'].mean()
# Out:
# day_of_the_week
# Weekday    16.311188
# Weekend    16.574833
# Name: cost_of_the_order, dtype: float64

# %%
df.groupby('day_of_the_week')['cost_of_the_order'].count()
# Out:
# day_of_the_week
# Weekday     547
# Weekend    1351
# Name: cost_of_the_order, dtype: int64

# %% [markdown]
# ### Conclusion and Recommendations
# The delivery time is a lot more in weekdays and it seems like all orders take more than 24 minutes to deliver. This might be due to more traffic congestion during the weekdays or a shortage of personnel. But this hasn't affected the ratings since the overall ratings are similar for weekday versus weekend. But there are a lot fewer orders received during the weekday and the slower delivery times could be a reason for it.

# %% [markdown]
# ### **Question 17:** What are your conclusions from the analysis? What recommendations would you like to share to help improve the business? (You can use cuisine type and feedback ratings to drive your business recommendations.) [6 marks]

# %% [markdown]
# ### Conclusions:
# *  Many more orders are received in the weekend compared to the weekdays.
# * The orders are fairly diversified in terms of the number of restaurants and the cuisine type.
# * Korean and Vietnamese cuisine orders have a lower than average rating.

# %% [markdown]
# ### Recommendations:
#
# * The company needs to get more orders during the weekdays. Perhaps reducing the delivery time might help increase the number of orders.
# * The number of orders as well as overall ratings are lower when it comes to Korean and Vietnamese food. Perhaps the company needs to onboard better restaurants to improve the ratings.

# %% [markdown]
# ---
